# %%
from win32com.client import Dispatch

f = open("testfile.txt","w+")

mapi = Dispatch("Outlook.Application").GetNamespace("MAPI")
inbox = mapi.GetDefaultFolder(6)
messages = list(inbox.Items)

# %%
def getPhone(string):
   lines = string.split("\n")
   return [line for line in lines if line.lower().startswith("tel") or line.lower().startswith("mobil")]

contacts = {}
for message in messages:
   try:
      phone = getPhone(message.Body)
      if phone:
         contacts[message.Sender.name] = phone
   except:
      continue

contacts
# Out:
# {'Jonathan.Seifert@partner.bmw.de': ['Tel.: +49 (0) 8152 / 999 411\r',
#   'Mobil: +49 171 2939712 \r'],
#  'Michael.Ott@bmw.de': ['Tel.: +49 89 382 32306\r',
#   'Mobil: +49 151 601 32306\r',
#   'Tel.: +49 (0) 8152 / 999 411\r',
#   'Mobil: +49 171 2939712                                                                     \r'],
#  'ITSM-Suite': ['Telefonnummer: 015165498446\r'],
#  'Nandish.Shah@partner.bmw.de': ['Tel.: +4915127135244\r',
#   'Mobil: +4915127135244\r'],
#  'CAE Software und Systems GmbH': ['Tel.: +49 (0)5241 21142-0, Fax: +49 (0)5241 21142-29 \r'],
#  'SI Scientific Instruments GmbH': ['Tel.: +49 30 7739 1590\r',
#   'Tel.: +49 8105 77940\r'],
#  'dominik.felsl@amitronics.de': ['Tel.: 08152 / 999 316\r',
#   'Tel:    +49 (0)371 531-36667\r'],
#  'Philip Wolbert': ['Mobile: +31 6 8369 1175\r'],
#  'norbert.ruemmler@amitronics.de': ['Tel.+49 (0) 89 35064 858\r',
#   'Telefon: 089 – 4272 4553, Fax: 089 – 4272 4554\r',
#   'Telefon: 0180-600-585-0 (tel: +491806005850)*\r'],
#  'Felix.Imrich@partner.bmw.de': ['Tel.: +49 (0) 89 / 3506 4858\r',
#   'Tel: +49-151-56389241\r'],
#  'Stefan.Nebelmeir@bmw.de': ['Tel: +49-89-382-27750\r',
#   'Mobil: +49-151-601-27750\r'],
#  'Rothfeld, Raoul': ['Tel: +49 (0) 711 / 970 - 1831\r'],
#  'HiFi Loesungen Strassacker': ['Tel: -unspecified-\r',
#   'Telephone: +49-(0)721-9703724 \r'],
#  'info@lautsprechershop.de': ['Tel/Fax: +49 (0)721-9703724/25  \r',
#   'Tel/Fax: +49 (0)721-9703724/25  \r'],
#  'Lukas.Binder@partner.bmw.de': ['Tel.: +49 (0) 89 / 35064 858\r',
#   'Tel: +49-15165498554\r'],
#  'Eigenbrod, Hartmut': ['Tel: +49 (0) 711 / 970 - 1831\r'],
#  'Lautsprechershop (Lager)': ['Tel.: 0049-(0)721-35230965, Fax: 0049-(0)721-9703725 \r'],
#  'sonja.greppmair@amitronics.de': ['Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 89 35064858\r'],
#  'Jörn Albrecht': ['Tel.:     +49 (0) 421 597 094 27\r',
#   'Telefon +49 711 970‐1326\r',
#   'Mobile  +49 152 331 49388\r'],
#  'Sielaff, Lennard': ['Telefon +49 711 970‐1326\r',
#   'Mobile  +49 152 331 49388\r'],
#  'Amitronics GmbH': ['Tel.: +49 (0) 8152 999 411\r'],
#  'René Schnitzer': ['Tel: +49-(0) 89 35064858\r'],
#  'Simon Böhm': ['Tel.: +49 (0) 8152 / 999 411\r'],
#  'Roland.Perian@bmw.de': ['Tel.+49 (0) 8152 999 411\r'],
#  'Philipp.PW.Wagner@bmw.de': ['Tel.: 08152 / 999 411\r'],
#  'timo.ziegler@meshparts.de': ['mobile: +49 1522 4832350\r'],
#  'claudia.kiss@amitronics.de': ['Tel.: +49 (0) 151 / 5631 9433| Email: claudia.kiss@amitronics.de \r',
#   'Tel.: +49 (0) 89 35064 858 | Fax: +49 (0) 89 35604 861\r',
#   'Tel.: +49 (0) 151 / 5631 9433| Email: claudia.kiss@amitronics.de <mailto:claudia.kiss@amitronics.de>  \r',
#   'Tel.: +49 (0) 89 35064 858 | Fax: +49 (0) 89 35604 861\r',
#   'Tel.: +49 (0) 151 / 5631 9433| Email: claudia.kiss@amitronics.de <mailto:claudia.kiss@amitronics.de>  \r',
#   'Tel.: +49 (0) 89 35064 858 | Fax: +49 (0) 89 35604 861\r'],
#  'Tino.Kloepfer@partner.bmwgroup.com': ['Tel: +49-89-382-38466\r',
#   'Mobil: +49-151-601-38466\r'],
#  'Rene Schnitzer@aol': ['Tel: +49-(0)8152-999 413\r'],
#  'Marek Schmidt': ['Tel.: +49 (0) 151 / 42024124 | Email: karl.benkler@amitronics.de <mailto:karl.benkler@amitronics.de>  \r',
#   'Tel. +49 (0) 89 35064 858\r',
#   'Tel: +49 (0)371 531-35898\r'],
#  'Schmidt, Johannes': ['Telefon: 0241 963-1210\r',
#   'Telefax: 0241 963-1214\r',
#   'Mobil: 0152 535 192 12\r',
#   'Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 8152 / 999 411\r'],
#  'simon.boehm@amitronics.de': ['Tel.: +49 (0) 8152 / 999 411 \r'],
#  'alexandru.dadalau@meshparts.de': ['mobile: +49 1522 4841115\r'],
#  'Karl Benkler': ['Tel.:+49 (0) 151 / 42024124 | Email: karl.benkler@amitronics.de\r',
#   'Tel.: +49 (0) 8152 / 999 411\r'],
#  'Rene.Schnitzer@partner.bmw.de': ['Tel: +49-(0)8152-999 411\r',
#   'Telefon: +49 (0) 89-382-30552                             \r',
#   'Mobil: +49 (0) 151-601-30552\r'],
#  'Mrosek, Florian': ['Telefon: 0241 963 1208\r',
#   'Telefax: 0241 963 1214\r',
#   'Mobil: 0157 / 50354028\r',
#   'Telefon: 07961 9256 0\r',
#   'Telefax: 07961 9256 211\r'],
#  'Hubert Steigerwald [h.steigerwald@sensorik-bayern.de]': ['Telefon\r',
#   'Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 8152 / 999 411\r',
#   'Telefon\r'],
#  'Birte Wienberg-Müller': ['Telefonkonferenz-ID: 577 254 053# \r', 'Tel.\r'],
#  'Ghesquiere, Pol': ['Mobil: +49 172 8217949\r',
#   'Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 8152 / 999 411\r',
#   'Mobil: +49 172 8217949\r'],
#  'Yvonne Mueller': ['Tel.+49 (0) 8152 999 411\r', 'Tel. +49 30 310078-436\r'],
#  'karl.benkler@amitronics.de': ['Tel.: +49 (0) 151 / 42024124 | Email: karl.benkler@amitronics.de <mailto:karl.benkler@amitronics.de>  \r',
#   'Tel. +49 (0) 89 35064 858\r',
#   'Tel.: +49 (0) 151 / 42024124 | Email: karl.benkler@amitronics.de <mailto:karl.benkler@amitronics.de>  \r',
#   'Tel. +49 (0) 89 35064 858\r',
#   'Tel.: +49 (0) 151 / 42024124 | Email: karl.benkler@amitronics.de <mailto:karl.benkler@amitronics.de>  \r',
#   'Tel. +49 (0) 89 35064 858\r',
#   'Tel.: +49 (0) 151 / 42024124 | Email: karl.benkler@amitronics.de <mailto:karl.benkler@amitronics.de>  \r',
#   'Tel. +49 (0) 89 35064 858\r',
#   'Tel.: +49 (0) 151 / 42024124 | Email: karl.benkler@amitronics.de <mailto:karl.benkler@amitronics.de>  \r',
#   'Tel. +49 (0) 89 35064 858\r'],
#  'Vossmann, Dirk, Dr. (EPS2)': ['Tel        +49 170 911 3418\r'],
#  'Christian.Erhard@partner.bmw.de': ['Tel.+49 (0) 89 35064 858\r'],
#  'Rzepka, Sven': ['Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 8152 / 999 411\r',
#   'Mobil:    +49-176-4456-9686\r'],
#  'Michael.Faulwasser@bmw.de': ['Tel: +49-89-382-13902\r'],
#  'amitronicsgmbh@aol.com': ['Tel.+49 (0) 8152 999 411\r'],
#  'Soremski, Ilona': ['Tel.:  +49(0)371-45001-220\r'],
#  'Seifert Jonathan, KFP Ingenieure GmbH': ['Tel. +49 (4161) 7401-588 \r'],
#  'Mohammad.Dina@partner.bmw.de': ['Mobil: +49 160 7695 974\r'],
#  'Fraunhofer ENAS': ['Telefon +49 371 45001-421 \r'],
#  'Bergelt, Jörg': ['Tel.: +49 (0) 3722 / 59 14 10\r',
#   'Tel.: +49 (0) 8152 999 411\r',
#   'Tel.: +49 (0) 3722 / 59 14 23\r'],
#  'Ines Brabandt': ['Tel.: +49 371 33562670\r'],
#  'SQL-Operation@bmw.de': ['Tel.: +91-9121424147 (primary) \r',
#   'Tel.: +91-9100624147 (secondary)\r',
#   'Tel.: +91-9121424147 (primary) \r',
#   'Tel.: +91-9100624147 (secondary)\r',
#   'Mobile: +1-864-906-0194\r',
#   'Mobile: +1-864-906-0194\r',
#   'Mobile: +1-864-906-0194\r',
#   'Tel.+49 (0) 8152 999 411\r',
#   'Mobil: +49 151 2713 5244\r'],
#  'Christian Erhard': ['Tel.: 08152 / 999 304\r'],
#  'andreas.hofer@amitronics.de': ['Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 89 35064858\r'],
#  'Meier-Scupin, Ruth': ['Tel. +49 (0)89 5108963-022\r'],
#  'Baldur.Tiesler@bmw.de': ['Tel: +49-89-382-38466\r',
#   'Mobil: +49-151-601-38466\r'],
#  'Alfred Neumeier, Neume1er EDV-Service': ['Tel. 089 90776748\r',
#   'Mobil 0151 55608035\r'],
#  'Marco Bauer': ['Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 89 35064858\r'],
#  'ASAM e.V.': ['Tel:  + 49 8102 8061-60\t\r'],
#  'Info@vwgroupsupply.com': ['Telefon:+ 49 - 5361 - 93 30 99\r'],
#  'Andreas.Hofer@partner.bmw.de': ['Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de\r',
#   'Tel.: +49 (0) 8152 / 999 411\r'],
#  'B2BTeam@vwgroupsupply.com': ['Tel. +49 5361 9-33099\r'],
#  'Lukas Berbuer': ['Tel.: +49 (0) 151 / 42024124 | Email: karl.benkler@amitronics.de <mailto:karl.benkler@amitronics.de>  \r',
#   'Tel. +49 (0) 89 35064 858\r',
#   'Tel.: +49 (0) 151 / 42024124 | Email: karl.benkler@amitronics.de <mailto:karl.benkler@amitronics.de>  \r',
#   'Tel. +49 (0) 89 35064 858\r',
#   'Tel.: +49 (0) 151 / 42024124 | Email: karl.benkler@amitronics.de <mailto:karl.benkler@amitronics.de>  \r',
#   'Tel. +49 (0) 89 35064 858\r',
#   'Tel.: +49 (0) 151 / 42024124 | Email: karl.benkler@amitronics.de <mailto:karl.benkler@amitronics.de>  \r',
#   'Tel. +49 (0) 89 35064 858\r'],
#  'Nelles, Robert (EAN6)': ['Mobil     +49 1523 911 – 5468\r'],
#  'Christian.Bloch@bmw.de': ['Tel: +49-89-382-38466\r',
#   'Mobil: +49-151-601-38466\r'],
#  'Aymelek, Tetiana, Dr. (EEC3)': ['Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 89 35064858\r'],
#  'Michael Kessler': ['Mobil: +49 (0) 1514 / 2052696\r'],
#  'Enver Coban': ['Tel 05731 8694-511 | Fax 05731 8694-413\r'],
#  'Marcel Szedelyi': ['Telefon:\t +49 6432 9139 720\t \r',
#   'Tel.: +49-15165498446 | Email:Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 89 35064858\r',
#   'Tel.: +49-15165498446 | Email:Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 89 35064858\r'],
#  'ICO Innovative Computer GmbH': ['Tel.: 06432-9139-720 \r'],
#  'Jiayi Wang': ['Telefon: 089 / 3506 4858\r',
#   'Mobil: 0151-42064924\r',
#   'Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 89 35064858\r'],
#  'Nelles, Robert (EAN5)': ['Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 89 35064858\r'],
#  'felix.imrich@amitronics.de': ['Tel.: +49 (0) 89 35064858\r'],
#  'Florian.Schneeweiss@bmw.de': ['Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 89 35064858\r'],
#  'Shenhui.He@partner.bmw.de': ['Tel.+49 (0) 89 35064 858\r'],
#  'Yannic Wolf': ['Mobile  +49 152 331 49388\r'],
#  'Kothe, Melvin (EEC3)': ['Mobil    +49 1764 2581214\r'],
#  'ines.brabandt@amitronics.de': ['Tel. +49 (0)89 5108963-0131\r'],
#  'Johann Haertl': ['Tel.: +4996317980216 \r', 'Mobil: +49 151 11699880\r'],
#  'Welker.Reinhold': ['Tel: +49 (0)89 45200-3995 | Fax: +49 (0)89 45200-8621 | Mobil: +49 (0)176 14520185 \r',
#   'Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 89 35064858\r'],
#  'Bjoern.Sasse@partner.bmw.de': ['Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 89 35064858\r'],
#  'FIPS': ['Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 89 35064858\r'],
#  'Valentin Plenk': ['Tel.: +4996317980216 \r', 'Mobil: +49 151 11699880\r'],
#  'francesco.urru@amitronics.de': ['Mobil: +49 151 56370385\r'],
#  'michael.kessler@amitronics.de': ['Mobil: +49 (0) 151 – 420 52 696\r'],
#  'BMW PAINTS': ['Telefonnummer 089-382- 55555\r',
#   'Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 89 35064858\r',
#   'Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 89 35064858\r'],
#  'Walter, Gerald': ['Tel.: + 49 (0)371 9104 195, Fax: + 49 (0)371 9104 105 \r',
#   'Tel.: +49 (0) 151 / 42024124 | Email: karl.benkler@amitronics.de <mailto:karl.benkler@amitronics.de>  \r',
#   'Tel. +49 (0) 89 35064 858\r'],
#  'Matthias Streller [m.streller@sensorik-bayern.de]': ['Telefon\r'],
#  'tsr': ['Tel.: +49 (0) 89 35064 858\r'],
#  'Maximilian Huber': ['Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 89 35064858\r'],
#  'Kirill Delov': ['Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 89 35064858\r'],
#  'Peter.Lachowski@partner.bmw.de': ['Tel.: +49 (0) 8152 / 999 411\r',
#   'Mobil: +49 151 56319434                                     \r'],
#  'Ludwig Mayerhofer': ['Tel.: +4992316036483 \r',
#   'Tel.: +49 (0) 151 / 42024124 | Email: karl.benkler@amitronics.de <mailto:karl.benkler@amitronics.de>  \r',
#   'Tel. +49 (0) 89 35064 858\r',
#   'Tel.: +4992316036483 \r',
#   'Tel.: +49 (0) 151 / 42024124 | Email: karl.benkler@amitronics.de <mailto:karl.benkler@amitronics.de>  \r',
#   'Tel. +49 (0) 89 35064 858\r'],
#  'Christian Birzer': ['Telefon: +49 89 200 65 89 0 | Mobil: +49 172 762 23 43 | christian.birzer@plastivation.com <mailto:christian.birzer@plastivation.com>  | www.plastiVation.com <http://www.plastivation.com/> \r'],
#  'Weber, Gabriel (T4-35)': ['Telefonkonferenz-ID: 560 393 86# \r'],
#  'Wu, Xinyang': ['Telefon +49 711 970-3673\r'],
#  'Georgi, Christian': ['Tel.: +49 (0) 3722 / 59 14 23\r',
#   'Tel.: +49 (0) 151 / 42024124 | Email: karl.benkler@amitronics.de <mailto:karl.benkler@amitronics.de>  \r',
#   'Tel. +49 (0) 89 35064 858\r',
#   'Tel.: +49 (0) 3722 / 59 14 23\r',
#   'Tel.: +49 (0) 151 / 42024124 | Email: karl.benkler@amitronics.de <mailto:karl.benkler@amitronics.de>  \r',
#   'Tel. +49 (0) 89 35064 858\r'],
#  'Frank.Steinbach@partner.bmw.de': ['Tel.+49 (0) 89 35064 858\r'],
#  'Rottler, Liv (EEC3)': ['Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 89 35064858\r'],
#  'KNOBLAUCH Martin': ['Tel.+49 (0) 89 35064 858\r'],
#  'Henrich, Markus, Dr.rer.nat. (EPV3)': ['Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 89 35064858\r'],
#  'Gutierrez Guzman, Francisco': ['Tel: +49 241 80-95604\r',
#   'Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 89 35064858\r'],
#  'Lucas Kutscher - areto consulting': ['Tel.: +49-15165498446 | Email: Andreas.Hofer@amitronics.de <mailto:Andreas.Hofer@amitronics.de> \r',
#   'Tel.: +49 (0) 89 35064858\r'],
#  'Reis, Ann-Kathrin': ['Tel. +49 (0)89 5108963-0131\r'],
#  'Stefan Gottwald [s.gottwald@sensorik-bayern.de]': ['Telefon\r',
#   'Telefon\r',
#   'Telefon\r',
#   'Telefon\r'],
#  'Andreas Hofmeister [a.hofmeister@sensorik-bayern.de]': ['Telefon\r']}

# %%
# Out:
# 'OpenPGP message\r\n\r\n\r\nPlease wait while the message is being decrypted / verified...'
