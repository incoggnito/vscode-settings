# %%
from win32com.client import Dispatch
import win32com
import os
import sys

f = open("testfile.txt","w+")

mapi = Dispatch("Outlook.Application").GetNamespace("MAPI")
inbox = mapi.GetDefaultFolder(6)
messages = list(inbox.Items)

# %%
import re
def getPhone(string):
   set(re.findall(r"((?:\d{3}|\(\d{3}\))?(?:\s|-|\.)?\d{3}(?:\s|-|\.)\d{4})", string))

contacts = {}
for message in messages:
   try:
      phone = getPhone(message.Body)
      if phone:
         contacts[message.Sender.name] = phone
   except:
      continue

contacts
# Out:
# {'Kundenservice 1&1 Internet SE': None,
#  'Jonathan.Seifert@partner.bmw.de': None,
#  'Michael.Ott@bmw.de': None,
#  'ITSM-Suite': None,
#  'Nandish.Shah@partner.bmw.de': None,
#  'b2b.no-reply@bmw.de': None,
#  'CAE Software und Systems GmbH': None,
#  'aspr-b2x@bmw.de': None,
#  'SI Scientific Instruments GmbH': None,
#  'BMWGroupAkademie@bmwgroup.com': None,
#  'academy@nextwork.de': None,
#  'IhrPortal@portal-bereich.de': None,
#  'admin@office-loesung.de': None,
#  'Andreas.Hofer@partner.bmw.de': None,
#  'dominik.felsl@amitronics.de': None,
#  'Philip Wolbert': None,
#  'Lukas Berbuer': None,
#  'norbert.ruemmler@amitronics.de': None,
#  'Felix.Imrich@partner.bmw.de': None,
#  'Stefan.Nebelmeir@bmw.de': None,
#  'Rothfeld, Raoul': None,
#  'Microsoft Invitations': None,
#  'HiFi Loesungen Strassacker': None,
#  'info@lautsprechershop.de': None,
#  'Lukas.Binder@partner.bmw.de': None,
#  'Eigenbrod, Hartmut': None,
#  'Lautsprechershop (Lager)': None,
#  'sonja.greppmair@amitronics.de': None,
#  'Jörn Albrecht': None,
#  'Sielaff, Lennard': None,
#  'Coursera': None,
#  'Sebastian Helmschrott': None,
#  'Audiomatica Srl': None,
#  'Amitronics GmbH': None,
#  'René Schnitzer': None,
#  'Simon Böhm': None,
#  'Roland.Perian@bmw.de': None,
#  'Philipp.PW.Wagner@bmw.de': None,
#  'simon.boehm@amitronics.de': None,
#  'timo.ziegler@meshparts.de': None,
#  'claudia.kiss@amitronics.de': None,
#  'Andreas Hofer': None,
#  'Tino.Kloepfer@partner.bmwgroup.com': None,
#  'Rene Schnitzer@aol': None,
#  'Marek Schmidt': None,
#  'Schmidt, Johannes': None,
#  'Anita Garcia': None,
#  'Shenhui He': None,
#  'alexandru.dadalau@meshparts.de': None,
#  'GitLab': None,
#  'asante richard': None,
#  'Marek Schmidt über TUCcloud': None,
#  'Karl Benkler': None,
#  'Christopher Baylon': None,
#  'Nextcloud': None,
#  'Rene.Schnitzer@partner.bmw.de': None,
#  'Karl Benkler (@KarlBe)': None,
#  'Maximilian Huber': None,
#  'Lilly Jones': None,
#  'Mrosek, Florian': None,
#  'Pascal Richter': None,
#  'Shenhui He (@hshuigg0730)': None,
#  'Simon Böhm (@DiscountCode)': None,
#  'Hubert Steigerwald [h.steigerwald@sensorik-bayern.de]': None,
#  'Birte Wienberg-Müller': None,
#  'Ghesquiere, Pol': None,
#  'Yvonne Mueller': None,
#  'VDI/VDE-IT Webevent': None,
#  'Ioannis Giakoumelos': None,
#  'karl.benkler@amitronics.de': None,
#  'Michael.Faulwasser@bmw.de': None,
#  'Vossmann, Dirk, Dr. (EPS2)': None,
#  'RAAB Tobias': None,
#  'KNOBLAUCH Martin': None,
#  'Christian.Erhard@partner.bmw.de': None,
#  'Rzepka, Sven': None,
#  'Matrix Notifications': None,
#  'amitronicsgmbh@aol.com': None,
#  'Soremski, Ilona': None,
#  'Mail Delivery System': None,
#  'Seifert Jonathan, KFP Ingenieure GmbH': None,
#  'Falschemaut': None,
#  'Miguel.JR.Gonzalez@partner.bmw.de': None,
#  'Mohammad.Dina@partner.bmw.de': None,
#  'Commercial Desk': None,
#  'Fraunhofer ENAS': None,
#  'Kaulfersch, Eberhard': None,
#  'Bergelt, Jörg': None,
#  'Ines Brabandt': None,
#  'SQL-Operation@bmw.de': None,
#  'Christian Erhard': None,
#  'andreas.hofer@amitronics.de': None,
#  'Telekom - <No-Reply>': None,
#  'Meier-Scupin, Ruth': None,
#  'Kontron': None,
#  'Baldur.Tiesler@bmw.de': None,
#  'Alfred Neumeier, Neume1er EDV-Service': None,
#  'Marco Bauer': None,
#  'ASAM e.V.': None,
#  'Plesk KAV': None,
#  'noreply@pingidentity.com': None,
#  'Info@vwgroupsupply.com': None,
#  'B2BTeam@vwgroupsupply.com': None,
#  'Docker': None,
#  'invest.westernzone': None,
#  'Bise, Nicole': None,
#  'Stefan von Indeed': None,
#  'Hugo von talentbay': None,
#  'bewerbung@amitronics.de': None,
#  'Industrial IoT Shop': None,
#  'Nelles, Robert (EAN6)': None,
#  'Christian.Bloch@bmw.de': None,
#  'Aymelek, Tetiana, Dr. (EEC3)': None,
#  'SupplierAssurance.com': None,
#  'Nikoltchovska, Alexandra (EEC3)': None,
#  'Michael Kessler': None,
#  'Doodle': None,
#  'Christian Tsobgang': None,
#  'Indeed für Arbeitgeber': None,
#  'Michael': None,
#  'Valentin Plenk': None,
#  'Enver Coban': None,
#  'Sandra Karhof': None,
#  'Klara Möllers': None,
#  'Marcel Szedelyi': None,
#  'ICO Innovative Computer GmbH': None,
#  'Nikola.Ljubic@bmw.de': None,
#  'michael.kessler@amitronics.de': None,
#  'Jiayi Wang': None,
#  'Lorenz Saumweber': None,
#  'Nelles, Robert (EAN5)': None,
#  'felix.imrich@amitronics.de': None,
#  'Lukas Binder': None,
#  'Florian.Schneeweiss@bmw.de': None,
#  'Shenhui.He@partner.bmw.de': None,
#  'Yannic Wolf': None,
#  'Birte Wienberg': None,
#  'Kothe, Melvin (EEC3)': None,
#  'Daniel Jansen': None,
#  'ines.brabandt@amitronics.de': None,
#  'Johann Haertl': None,
#  'ENX Association (info)': None,
#  'ip': None,
#  'Welker.Reinhold': None,
#  'Bjoern.Sasse@partner.bmw.de': None,
#  'BMW PAINTS': None,
#  'Florian Gleich': None,
#  'FIPS': None,
#  'Tom Wright': None,
#  'Tanja Reinel-Tröger': None,
#  'Udemy': None,
#  'AMITRONICS EXTERN CLOUD': None,
#  'francesco.urru@amitronics.de': None,
#  'Matthias Streller [m.streller@sensorik-bayern.de]': None,
#  'Peter.Lachowski@partner.bmw.de': None,
#  'Walter, Gerald': None,
#  'tsr': None,
#  'GitHub': None,
#  'Kirill Delov': None,
#  'Microsoft Evaluation Center': None,
#  'sslwebserver@actalis.it': None,
#  'Ludwig Mayerhofer': None,
#  'Ortwin.Beer@partner.bmw.de': None,
#  'Christian Birzer': None,
#  'AMITRONICS CLOUD': None,
#  'Rottler, Liv (EEC3)': None,
#  'Lucas Kutscher - areto consulting': None,
#  'Weber, Gabriel (T4-35)': None,
#  'Wu, Xinyang': None,
#  'Georgi, Christian': None,
#  'Frank.Steinbach@partner.bmw.de': None,
#  'Microsoft 365 Message center': None,
#  'Welotec News': None,
#  'Henrich, Markus, Dr.rer.nat. (EPV3)': None,
#  'p463402p93': None,
#  'Thomas Weber': None,
#  'Gutierrez Guzman, Francisco': None,
#  'Rottler, Liv (EEC3) in Microsoft Teams': None,
#  'Reis, Ann-Kathrin': None,
#  'Thomas, Claus (EGA5)': None,
#  'Stefan Gottwald [s.gottwald@sensorik-bayern.de]': None,
#  'Karl Benkler (@Karl)': None,
#  'Andreas Hofmeister [a.hofmeister@sensorik-bayern.de]': None}
